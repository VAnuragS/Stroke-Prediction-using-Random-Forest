# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
plt.style.use('dark_background')
sns.set_palette("Set2")

# %%
df=pd.read_csv("../input/stroke-prediction-dataset/healthcare-dataset-stroke-data.csv")
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df.isnull().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
sns.boxplot(x=df['gender'],y=df['bmi'])
# Out:
# <AxesSubplot:xlabel='gender', ylabel='bmi'>

# %%
sns.scatterplot(data=df,x='bmi',y='age')
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='age'>

# %% [markdown]
# grouping the age into toddler teen adult and senior and then impute the bmi values based on the median.

# %%
age_group=[]
for i in df['age']:
    if i<2.0:
        age_group.append('Toddler')
    elif i>2.0 and i<=19.0:
        age_group.append('Teen')
    elif i>19.0 and i<60.0:
        age_group.append('Adult')
    else:
        age_group.append('Senior')
df['age_group']=age_group
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke age_group
# 0       1    Senior
# 1       1    Senior
# 2       1    Senior
# 3       1     Adult
# 4       1    Senior

# %%
fig = px.box(df, x="age_group", y="bmi",color="gender")
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="89f847d7-9c57-45e0-8a7f-d678498b0066" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89f847d7-9c57-45e0-8a7f-d678498b0066")) {                    Plotly.newPlot(                        "89f847d7-9c57-45e0-8a7f-d678498b0066",                        [{"alignmentgroup":"True","hovertemplate":"gender=Male<br>age_group=%{x}<br>bmi=%{y}<extra></extra>","legendgroup":"Male","marker":{"color":"#636efa"},"name":"Male","notched":false,"offsetgroup":"Male","orientation":"v","showlegend":true,"x":["Senior","Senior","Senior","Senior","Senior","Senior","Senior","Adult","Senior","Senior","Senior","Adult","Senior","Adult","Adult","Adult","Senior","Adult","Senior","Adult","Senior","Adult","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Adult","Senior","Senior","Adult","Adult","Adult","Adult","Senior","Adult","Senior","Senior","Adult","Adult","Adult","Senior","Adult","Senior","Senior","Senior","Senior","Senior","Senior","Adult","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Adult","Senior","Senior","Senior","Senior","Senior","Adult","Adult","Senior","Adult","Senior","Senior","Senior","Senior","Senior","Adult","Senior","Senior","Senior","Senior","Senior","Senior","Senior","Adult","Senior","Senior","Adult","Senior","Senior","Senior","Adult","Senior","Adult","Senior","Teen","Adult","Teen","Senior","Adult","Senior","Adult","Adult","Teen","Adult","Teen","Teen","Senior","Adult","Senior","Adult","Senior","Adult","Adult","Adult","Adult","Adult","Senior","Adult","Teen","Adult","Adult","Senior","Teen","Adult","Teen","Adult","Senior","Senior","Adult","Adult","Senior","Adult","Adult","Adult","Adult","Adult","Teen","Adult","Teen","Teen","Senior","Adult","Adult","Adult","Adult","Adult","Senior","Adult","Adult","Teen","Senior","Teen","Senior","Senior","Adult","Adult","Senior","Adult","Senior","Adult","Adult","Teen","Adult","Senior","Adult","Senior","Teen","Adult","Adult","Teen","Senior","Adult","Senior","Senior","Adult","Adult","Senior","Adult","Teen","Teen","Adult","Adult","Adult","Adult","Senior","Senior","Teen","Adult","Adult","Senior","Adult","Adult","Adult","Adult","Teen","Senior","Adult","Senior","Senior","Adult","Adult","Adult","Senior","Adult","Adult","Teen","Teen","Adult","Senior","Adult","Teen","Adult","Adult","Teen","Teen","Senior","Adult","Adult","Adult","Adult","Teen","Adult","Adult","Teen","Senior","Teen","Adult","Adult","Adult","Teen","Adult","Adult","Adult","Teen","Adult","Adult","Teen","Adult","Adult","Senior","Adult","Adult","Adult","Senior","Adult","Adult","Adult","Adult","Adult","Adult","Adult","Teen","Senior","Adult","Senior","Senior","Senior","Senior","Adult","Adult","Adult","Senior","Teen","Adult","Senior","Senior","Teen","Adult","Adult","Adult","Adult","Adult","Adult","Adult","Senior","Adult","Adult","Teen","Adult","Senior","Adult","Teen","Teen","Adult","Teen","Adult","Senior","Adult","Senior","Adult","Adult","Adult","Adult","Senior","Teen","Adult","Senior","Adult","Adult","Adult","Adult","Senior","Teen","Senior","Teen","Teen","Senior","Teen","Teen","Senior","Adult","Adult","Adult","Adult","Adult","Adult","Teen","Adult","Adult","Senior","Senior","Adult","Senior","Senior","Adult","Teen","Adult","Toddler","Senior","Adult","Adult","Senior","Adult","Senior","Adult","Senior","Adult","Adult","Senior","Adult","Adult","Adult","Senior","Teen","Adult","Senior","Senior","Senior","Adult","Senior","Adult","Adult","Senior","Adult","Teen","Senior","Teen","Senior","Senior","Senior","Adult","Adult","Teen","Teen","Senior","Senior","Teen","Toddler","Teen","Adult","Adult","Adult","Teen","Adult","Adult","Senior","A ...

# %%
def impute_bmi(cols):
    bmi = cols[0]
    age_group = cols[1]
    gender = cols[2]
    if pd.isnull(bmi):
        if age_group == 'Senior':
            if gender == 'Male':
                return 29.0
            else:
                return 28.9
        elif age_group == 'Adult':
            if gender == 'Male':
                return 30.2
            else:
                return 28.8
        elif age_group == 'Teen':
            if gender == 'Male':
                return 20.6
            else:
                return 21.8
        else:
            if gender == 'Male':
                return 18.9
            else:
                return 18.05
    else:
        return bmi
df['bmi']=df[['bmi','age_group','gender']].apply(impute_bmi,axis=1)
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21  28.9     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke age_group
# 0       1    Senior
# 1       1    Senior
# 2       1    Senior
# 3       1     Adult
# 4       1    Senior

# %%
df.isnull().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# age_group            0
# dtype: int64

# %% [markdown]
# EDA

# %%
df.shape
# Out:
# (5110, 13)

# %%
df.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  5110.000000  5110.000000
# mean          106.147677    28.871027     0.048728
# std            45.283560     7.718561     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.625000     0.000000
# 50%            91.885000    28.300000     0.000000
# 75%           114.090000    32.800000     0.000000
# max           271.740000    97.600000     1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                5110 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
#  12  age_group          5110 non-null   object
# dtypes: float64(3), int64(4), object(6)
# memory usage: 519.1+ KB

# %%
# To check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
#storing categorical and continuous columns into separate lists for future purpose
con_cols=['age','avg_glucose_level','bmi']
cat_cols=[]
for i in df.columns:
    if i!='id' and i!='stroke' and i not in con_cols:
        cat_cols.append(i)
cat_cols
# Out:
# ['gender',
#  'hypertension',
#  'heart_disease',
#  'ever_married',
#  'work_type',
#  'Residence_type',
#  'smoking_status',
#  'age_group']

# %%
#Checking value in each categorical column
cat_cols.append('age_group')
for i in cat_cols:
    print(f'============Values in {i}============\n{df[i].value_counts()}\n------------------------')
# Out:
# ============Values in gender============
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64
# ------------------------
# ============Values in hypertension============
# 0    4612
# 1     498
# Name: hypertension, dtype: int64
# ------------------------
# ============Values in heart_disease============
# 0    4834
# 1     276
# Name: heart_disease, dtype: int64
# ------------------------
# ============Values in ever_married============
# Yes    3353
# No     1757
# Name: ever_married, dtype: int64
# ------------------------
# ============Values in work_type============
# Private          2925
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64
# ------------------------
# ============Values in Residence_type============
# Urban    2596
# Rural    2514
# Name: Residence_type, dtype: int64
# ------------------------
# ============Values in smoking_status============
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: smoking_status, dtype: int64
# ------------------------
# ============Values in age_group============
# Adult      2768
# Senior     1431
# Teen        791
# Toddler     120
# Name: age_group, dtype: int64
# ------------------------

# %%
df.drop(index = df[df['gender']=='Other'].index[0] ,axis=0,inplace=True)

# %%
fig,ax=plt.subplots(8,2,figsize=(15,35))
for index,i in enumerate(cat_cols):
    plt.suptitle("Visualizing Count of Categorical Columns",size=20)
    sns.countplot(data=df,x=i,ax=ax[index,0])
    sns.countplot(data=df,x=i,ax=ax[index,1],hue='stroke')

# %%
sns.countplot(data=df,x='stroke')
plt.show()

# %%
plt.title("Visualizing Count of classes")
plt.pie(np.array(df['stroke'].value_counts()),labels=['Non Stroke','Stroke'],explode=[0.3,0],autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# <h4>A huge imbalance of the classes is found! Would oversample the minority class.</h4>

# %%
fig,ax=plt.subplots(3,3,figsize=(15,15))
for index,i in enumerate(con_cols):
    plt.suptitle("Visualizing Distribution of Continuous Columns",size=20)
    sns.histplot(df[i],ax=ax[index,0],kde=True)
    sns.boxplot(data=df,x=i,ax=ax[index,1])
    sns.violinplot(data=df,x=i,ax=ax[index,2])

# %%
sns.pairplot(data=df,hue='stroke')

# %%
plt.figure(figsize=(6,6))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,fmt='0.2f')
plt.show()

# %% [markdown]
# <h5>Not much correlation between independent variables.</h5>

# %%
cat_cols.pop()
df_enc=pd.get_dummies(df[cat_cols],drop_first=True)
df_enc.head()
# Out:
#    hypertension  heart_disease  gender_Male  ever_married_Yes  \
# 0             0              1            1                 1
# 1             0              0            0                 1
# 2             0              1            1                 1
# 3             0              0            0                 1
# 4             1              0            0                 1
#
#    work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 0                       0                  1                        0
# 1                       0                  0                        1
# 2                       0                  1                        0
# 3                       0                  1                        0
# 4                       0                  0                        1
#
#    work_type_children  Residence_type_Urban  smoking_status_formerly smoked  \
# 0                   0                     1                               1
# 1                   0                     0                               0
# 2                   0                     0                               0
# 3                   0                     1                               0
# 4                   0                     0                               0
#
#    smoking_status_never smoked  smoking_status_smokes
# 0                            0                      0
# 1                            1                      0
# 2                            1                      0
# 3                            0                      1
# 4                            1                      0

# %%
df[df_enc.columns]=df_enc
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi  ... gender_Male  \
# 0        Private          Urban             228.69  36.6  ...           1
# 1  Self-employed          Rural             202.21  28.9  ...           0
# 2        Private          Rural             105.92  32.5  ...           1
# 3        Private          Urban             171.23  34.4  ...           0
# 4  Self-employed          Rural             174.12  24.0  ...           0
#
#    ever_married_Yes work_type_Never_worked  work_type_Private  \
# 0                 1                      0                  1
# 1                 1                      0                  0
# 2                 1                      0                  1
# 3                 1                      0                  1
# 4                 1                      0                  0
#
#    work_type_Self-employed  work_type_children  Residence_type_Urban  \
# 0                        0                   0                     1
# 1                        1                   0                     0
# 2                        0                   0                     0
# 3                        0                   0                     1
# 4                        1                   0                     0
#
#    smoking_status_formerly smoked  smoking_status_never smoked  \
# 0                               1                            0
# 1                               0                            1
# 2                               0                            1
# 3                               0                            0
# 4                               0                            1
#
#    smoking_status_smokes
# 0                      0
# 1                      0
# 2                      0
# 3                      1
# 4                      0
#
# [5 rows x 23 columns]

# %%
df.drop(cat_cols,axis=1,inplace=True)
df.head()
# Out:
#       id   age  avg_glucose_level   bmi  stroke age_group  gender_Male  \
# 0   9046  67.0             228.69  36.6       1    Senior            1
# 1  51676  61.0             202.21  28.9       1    Senior            0
# 2  31112  80.0             105.92  32.5       1    Senior            1
# 3  60182  49.0             171.23  34.4       1     Adult            0
# 4   1665  79.0             174.12  24.0       1    Senior            0
#
#    ever_married_Yes  work_type_Never_worked  work_type_Private  \
# 0                 1                       0                  1
# 1                 1                       0                  0
# 2                 1                       0                  1
# 3                 1                       0                  1
# 4                 1                       0                  0
#
#    work_type_Self-employed  work_type_children  Residence_type_Urban  \
# 0                        0                   0                     1
# 1                        1                   0                     0
# 2                        0                   0                     0
# 3                        0                   0                     1
# 4                        1                   0                     0
#
#    smoking_status_formerly smoked  smoking_status_never smoked  \
# 0                               1                            0
# 1                               0                            1
# 2                               0                            1
# 3                               0                            0
# 4                               0                            1
#
#    smoking_status_smokes
# 0                      0
# 1                      0
# 2                      0
# 3                      1
# 4                      0

# %%
df_final=df.drop(['id','age_group'],axis=1)
df_final.head()
# Out:
#     age  avg_glucose_level   bmi  stroke  gender_Male  ever_married_Yes  \
# 0  67.0             228.69  36.6       1            1                 1
# 1  61.0             202.21  28.9       1            0                 1
# 2  80.0             105.92  32.5       1            1                 1
# 3  49.0             171.23  34.4       1            0                 1
# 4  79.0             174.12  24.0       1            0                 1
#
#    work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 0                       0                  1                        0
# 1                       0                  0                        1
# 2                       0                  1                        0
# 3                       0                  1                        0
# 4                       0                  0                        1
#
#    work_type_children  Residence_type_Urban  smoking_status_formerly smoked  \
# 0                   0                     1                               1
# 1                   0                     0                               0
# 2                   0                     0                               0
# 3                   0                     1                               0
# 4                   0                     0                               0
#
#    smoking_status_never smoked  smoking_status_smokes
# 0                            0                      0
# 1                            1                      0
# 2                            1                      0
# 3                            0                      1
# 4                            1                      0

# %% [markdown]
# Oversampling of Minority Class

# %%
from imblearn.over_sampling import RandomOverSampler
oversample = RandomOverSampler(sampling_strategy='minority')
X=df_final.drop(['stroke'],axis=1)
y=df_final['stroke']
X_over, y_over = oversample.fit_resample(X, y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X_over,y_over,test_size=0.3,stratify=y_over,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_train[con_cols]=scaler.fit_transform(X_train[con_cols])
X_test[con_cols]=scaler.transform(X_test[con_cols])
X_train.head()
# Out:
#            age  avg_glucose_level       bmi  gender_Male  ever_married_Yes  \
# 9192  0.812953           1.395983  0.480747            1                 1
# 3629  0.139834           1.576720  1.460287            1                 1
# 9526  0.857827           1.846097  0.610392            1                 1
# 539  -0.533284          -0.681862  3.174481            0                 1
# 5479  0.992451           0.798075  0.451937            1                 1
#
#       work_type_Never_worked  work_type_Private  work_type_Self-employed  \
# 9192                       0                  0                        1
# 3629                       0                  0                        0
# 9526                       0                  1                        0
# 539                        0                  1                        0
# 5479                       0                  0                        1
#
#       work_type_children  Residence_type_Urban  \
# 9192                   0                     1
# 3629                   0                     0
# 9526                   0                     0
# 539                    0                     0
# 5479                   0                     0
#
#       smoking_status_formerly smoked  smoking_status_never smoked  \
# 9192                               0                            1
# 3629                               0                            1
# 9526                               1                            0
# 539                                0                            0
# 5479                               1                            0
#
#       smoking_status_smokes
# 9192                      0
# 3629                      0
# 9526                      0
# 539                       0
# 5479                      0

# %%
param_grid = {
'n_estimators': [50, 75,100, 150, 200,300],
}
rcv=RandomizedSearchCV(RandomForestClassifier(random_state=42),param_grid,cv=5)
rcv.fit(X_train,y_train)
y_pred_rcv=rcv.predict(X_test)
confusion_rcv=confusion_matrix(y_test,rcv.predict(X_test))
plt.figure(figsize=(8,8))
sns.heatmap(confusion_rcv,annot=True)
plt.xlabel("Predicted")
plt.ylabel("Actual")
print(classification_report(y_test,y_pred_rcv))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99      1458
#            1       0.98      1.00      0.99      1458
#
#     accuracy                           0.99      2916
#    macro avg       0.99      0.99      0.99      2916
# weighted avg       0.99      0.99      0.99      2916
